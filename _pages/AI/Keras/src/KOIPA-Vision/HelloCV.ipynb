# %% [markdown]
# <a href="https://colab.research.google.com/github/shpimit/shpimit.github.io/blob/master/_pages/AI/Keras/src/KOIPA-Vision/HelloCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글 드라이브 mount
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd gdrive/My Drive/Colab Notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
# !ls
# Out:
# '181123_실습0 (public).ipynb의 사본'
# '181123_실습1 (public).ipynb의 사본'
#  Activation_Function.ipynb
#  Day_03_02_gan.ipynb
#  Gan-Teacher.ipynb
# 'graph v2 (public).ipynb의 사본'
#  HelloCV.ipynb
# 'instagram API (public).ipynb의 사본'
#  Introduction_to_convnets.ipynb
# 'Keras.ipynb의 사본'
# 'lab.web-crawling-visualization.ipynb의 사본'
# 'lab.web-crawling-visualization.ipynb의 사본 (1)'
#  lena.jpg
#  MNIST.ipynb
#  placeHolderEx01.ipynb
# 'RL as Probabilistic Inference의 사본'
#  Untitled0.ipynb
#  Untitled1.ipynb
#  Untitled2.ipynb

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow

# img = cv.imread('lena.jpg')
img = cv.imread('lena.jpg', cv.IMREAD_GRAYSCALE)

if img is None:
  print('Image Load Failed!')
  exit()
  
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FC11257E9E8>
