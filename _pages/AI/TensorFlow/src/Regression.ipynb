# %%
# 임의의 선형 회귀 방정식 y = 0.1 * x + 0.3 데이터 생성하기
import numpy as np

num_points = 1000
vectors_set = []

for i in range(num_points):
    x1 = np.random.normal(0.0, 0.55)
    y1 = x1 * 0.1 + 0.3 + np.random.normal(0.0, 0.03) # 정규 분포(normal distribution)를 따르는 약간의 변동값 직선 불일치
    vectors_set.append([x1,y1])
    
x_data = [v[0] for v in vectors_set]
y_data = [v[1] for v in vectors_set]

# %%
# 데이터 Display 해보기
import matplotlib.pyplot as plt

plt.plot(x_data, y_data,'ro')
plt.legend()
plt.show()

# %%
import tensorflow as tf

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()

sess = tf.Session()
sess.run(init)

for step in range(8):
    sess.run(train)
    print(step, sess.run(W), sess.run(b))
    print(step, sess.run(loss))
    
    plt.plot(x_data, y_data,'ro')
    plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
    plt.xlabel('x')
    plt.xlim(-2,2)
    plt.ylim(0.1, 0.6)
    plt.ylabel('y')
    plt.legend()
    plt.show()
# Out:
# 0 [ 0.3220706] [ 0.29458952]
# 0 0.0150044
# 1 [ 0.25814322] [ 0.29589128]
# 1 0.0080118
# 2 [ 0.2127333] [ 0.29688707]
# 2 0.00448323
# 3 [ 0.18047591] [ 0.2975944]
# 3 0.00270268
# 4 [ 0.15756153] [ 0.29809687]
# 4 0.00180419
# 5 [ 0.14128408] [ 0.29845381]
# 5 0.00135081
# 6 [ 0.12972122] [ 0.29870737]
# 6 0.00112202
# 7 [ 0.12150743] [ 0.29888746]
# 7 0.00100658
