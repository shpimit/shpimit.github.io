# %%
import requests

# %%
def getDownload(url, param = None, retries = 3):
    resp = None
    
    try:
        resp = requests.get(url, params = param, headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36'})
        resp.raise_for_status()
    except requests.exceptions.HTTPError as e:
        if 500 <= resp.status_code < 600 and retries > 0:
            print('Retries : {0}'.format(retries))
            return getDownload(url, param, retries -1)
        else:
            print(resp.status_code)
            print(resp.reason)
            print(resp.request.headers)
            
    return resp

# %%
from bs4 import BeautifulSoup

# %%
url = "http://example.webscraping.com/places/default/index"

# %%
html = getDownload(url)
dom = BeautifulSoup(html.text,"lxml")

# %%
for tag in dom.select("a"):
    if(tag.has_attr("href")):
        print(tag["href"])
# Out:
# #
# /places/default/user/register?_next=/places/default/index
# /places/default/user/login?_next=/places/default/index
# /places/default/index
# /places/default/search
# /places/default/view/Afghanistan-1
# /places/default/view/Aland-Islands-2
# /places/default/view/Albania-3
# /places/default/view/Algeria-4
# /places/default/view/American-Samoa-5
# /places/default/view/Andorra-6
# /places/default/view/Angola-7
# /places/default/view/Anguilla-8
# /places/default/view/Antarctica-9
# /places/default/view/Antigua-and-Barbuda-10
# /places/default/index/1

# %%
from urllib.parse import urljoin

urljoin("http://www.naver.com","/search/about")
# Out:
# 'http://www.naver.com/search/about'

# %%
urljoin(url,"/places/default/user/register?_next=/places/default/index")
requests.compat.urljoin(url,"/places/default/user/register?_next=/places/default/index")
# Out:
# 'http://example.webscraping.com/places/default/user/register?_next=/places/default/index'

# %%
for tag in dom.select("a"):
    if(tag.has_attr("href")):
        href = tag["href"]
        print(href)
        
        if href.startswith("#"):
            print("Skipped: "+href)
        elif href.startswith("/"):
            print(requests.compat.urljoin(url,href))
#         print(tag["href"])
# Out:
# #
# Skipped: #
# /places/default/user/register?_next=/places/default/index
# http://example.webscraping.com/places/default/user/register?_next=/places/default/index
# /places/default/user/login?_next=/places/default/index
# http://example.webscraping.com/places/default/user/login?_next=/places/default/index
# /places/default/index
# http://example.webscraping.com/places/default/index
# /places/default/search
# http://example.webscraping.com/places/default/search
# /places/default/view/Afghanistan-1
# http://example.webscraping.com/places/default/view/Afghanistan-1
# /places/default/view/Aland-Islands-2
# http://example.webscraping.com/places/default/view/Aland-Islands-2
# /places/default/view/Albania-3
# http://example.webscraping.com/places/default/view/Albania-3
# /places/default/view/Algeria-4
# http://example.webscraping.com/places/default/view/Algeria-4
# /places/default/view/American-Samoa-5
# http://example.webscraping.com/places/default/view/American-Samoa-5
# /places/default/view/Andorra-6
# http://example.webscraping.com/places/default/view/Andorra-6
# /places/default/view/Angola-7
# http://example.webscraping.com/places/default/view/Angola-7
# /places/default/view/Anguilla-8
# http://example.webscraping.com/places/default/view/Anguilla-8
# /places/default/view/Antarctica-9
# http://example.webscraping.com/places/default/view/Antarctica-9
# /places/default/view/Antigua-and-Barbuda-10
# http://example.webscraping.com/places/default/view/Antigua-and-Barbuda-10
# /places/default/index/1
# http://example.webscraping.com/places/default/index/1

# %%
def getUrls(url, depth):
    
    if depth > 3:
        return None
    
    html = getDownload(url)
    
    if html.status_code != 200:
        return None
    
    dom = BeautifulSoup(html.text, "lxml")
    
    urls = []
    
    for tag in dom.select("a"):
        if(tag.has_attr("href")):
            href = tag["href"]
#             print(href)

            if href.startswith("http"):
                urls.append({"url":href, "depth":depth+1})
            if href.startswith("#"):
                print("Skipped: "+href)
            if href.startswith("/"):
                if len(href) > 2:
                    newUrl = requests.compat.urljoin(url,href)
    #                 print(requests.compat.urljoin(url,href))
                    if url != newUrl:
                        urls.append({"url":newUrl, "depth":depth+1})                
                if href.startswith("//"):
                    urls.append({"url":"http:"+href, "depth":depth+1})

                
    print("{0} {1} / {2}".format(">"*depth, url, len(urls)))

    return urls

# %%
import time
import random

time.sleep(1)
random.randint(1,3)
# Out:
# 1

# %%
queue = getUrls(url)
visited = [] # timestamp

while queue:
    time.sleep(random.randint(1,3))
    
    seed = queue.pop(0)
    links = getUrls(seed["url"], seed["depth"])
    
    if links != None:
        queue.extend(links)
    
    visited.append(seed)    
    target = [tag for tag in links if tag not in queue and visited]
    ""
    print("Queu: {0}, Links:{1}".format(len(queue), len(target)))
    
    queue.extend(target)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-6df88c057f54> in <module>
# ----> 1 queue = getUrls(url)
#       2 visited = [] # timestamp
#       3
#       4 while queue:
#       5     time.sleep(random.randint(1,3))
#
# TypeError: getUrls() missing 1 required positional argument: 'depth'

# %%
a = [1, 2]
b = [3]
a.append(b)
a
# Out:
# [1, 2, [3]]

# %%
a = [1, 2]
b = [3]
a.extend(b)
a
# Out:
# [1, 2, 3]

# %%
whos
# Out:
# Variable        Type             Data/Info
# ------------------------------------------
# BeautifulSoup   type             <class 'bs4.BeautifulSoup'>
# a               list             n=3
# b               list             n=1
# dom             BeautifulSoup    <!--[if HTML5]><![endif]-<...>f]-->\n</body>\n</html>\n
# getDownload     function         <function getDownload at 0x00000193E3371950>
# getUrls         function         <function getUrls at 0x00000193E4B627B8>
# href            str              /places/default/index/1
# html            Response         <Response [200]>
# links           list             n=0
# queue           list             n=150
# random          module           <module 'random' from 'C:<...>aconda3\\lib\\random.py'>
# requests        module           <module 'requests' from '<...>\\requests\\__init__.py'>
# seed            str              http://example.webscrapin<...>com/places/default/iso/ME
# tag             Tag              <a href="/places/default/index/1">Next &gt;</a>
# target          list             n=0
# time            module           <module 'time' (built-in)>
# url             str              http://example.webscrapin<...>.com/places/default/index
# urljoin         function         <function urljoin at 0x00000193E0E65598>
# visited         list             n=40

# %%
url = "https://www.google.com/search"
param = {"q":"파이썬"}

html = getDownload(url,param)
dom = BeautifulSoup(html.text,"lxml")

queue= []

for tag in dom.select(".r a > h3"):
    queue.append({"url":tag.find_parent()["href"], "depth":0})
#     print(tag.find_parent()["href"])

# %%
queue
# Out:
# [{'url': 'https://www.python.org/', 'depth': 0},
#  {'url': 'https://docs.python.org/ko/3/tutorial/index.html', 'depth': 0},
#  {'url': 'https://namu.wiki/w/Python', 'depth': 0},
#  {'url': 'https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC',
#   'depth': 0},
#  {'url': 'https://programmers.co.kr/learn/courses/2', 'depth': 0},
#  {'url': 'https://wikidocs.net/9', 'depth': 0},
#  {'url': 'https://wikidocs.net/43', 'depth': 0},
#  {'url': 'https://wikidocs.net/6', 'depth': 0},
#  {'url': 'https://wikidocs.net/13', 'depth': 0},
#  {'url': 'https://opentutorials.org/course/1750', 'depth': 0}]

# %%
# getUrls(queue[0])

depth = 0

while queue:
    seed = queue.pop(0)
    
    links = getUrls(seed["url"], seed["depth"])
    
    if links != None:
        queue.extend(links)
# Out:
# Skipped: #content
# Skipped: #python-network
# Skipped: #top
# Skipped: #site-map
# Skipped: #
# Skipped: #
# Skipped: #python-network
# Skipped: #python-network
#  https://www.python.org/ / 195
# Skipped: #the-python-tutorial
#  https://docs.python.org/ko/3/tutorial/index.html / 6
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #fn-1
# Skipped: #s-1
# Skipped: #s-2
# Skipped: #s-2.1
# Skipped: #s-2.2
# Skipped: #s-2.3
# Skipped: #s-2.4
# Skipped: #s-3
# Skipped: #s-3.1
# Skipped: #s-3.2
# Skipped: #s-4
# Skipped: #s-4.1
# Skipped: #s-4.2
# Skipped: #s-4.3
# Skipped: #s-4.4
# Skipped: #s-4.5
# Skipped: #s-4.6
# Skipped: #s-4.7
# Skipped: #s-4.8
# Skipped: #s-4.8.1
# Skipped: #s-5
# Skipped: #s-5.1
# Skipped: #s-6
# Skipped: #s-6.1
# Skipped: #s-6.2
# Skipped: #s-7
# Skipped: #s-7.1
# Skipped: #s-7.2
# Skipped: #s-8
# Skipped: #s-8.1
# Skipped: #s-8.2
# Skipped: #s-9
# Skipped: #s-9.1
# Skipped: #s-10
# Skipped: #s-10.1
# Skipped: #toc
# Skipped: #fn-2
# Skipped: #fn-3
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #fn-4
# Skipped: #toc
# Skipped: #fn-5
# Skipped: #fn-6
# Skipped: #fn-7
# Skipped: #fn-8
# Skipped: #fn-9
# Skipped: #fn-10
# Skipped: #fn-11
# Skipped: #fn-12
# Skipped: #toc
# Skipped: #toc
# Skipped: #fn-13
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #fn-14
# Skipped: #fn-15
# Skipped: #fn-16
# Skipped: #fn-17
# Skipped: #fn-18
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #fn-19
# Skipped: #fn-20
# Skipped: #toc
# Skipped: #toc
# Skipped: #fn-21
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #fn-22
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #toc
# Skipped: #fn-23
# Skipped: #toc
# Skipped: #fn-24
# Skipped: #fn-25
# Skipped: #toc
# Skipped: #rfn-1
# Skipped: #rfn-2
# Skipped: #rfn-3
# Skipped: #rfn-4
# Skipped: #rfn-5
# Skipped: #rfn-6
# Skipped: #rfn-7
# Skipped: #rfn-8
# Skipped: #rfn-9
# Skipped: #rfn-10
# Skipped: #rfn-11
# Skipped: #rfn-12
# Skipped: #rfn-13
# Skipped: #rfn-14
# Skipped: #rfn-15
# Skipped: #rfn-16
# Skipped: #rfn-17
# Skipped: #rfn-18
# Skipped: #rfn-19
# Skipped: #rfn-20
# Skipped: #rfn-21
# Skipped: #rfn-22
# Skipped: #rfn-23
# Skipped: #rfn-24
# Skipped: #rfn-25
# Skipped: #top
# Skipped: #bottom
#  https://namu.wiki/w/Python / 429
# Skipped: #mw-head
# Skipped: #p-search
# Skipped: #cite_note-1
# Skipped: #cite_note-파이썬_역사-2
# Skipped: #cite_note-3
# Skipped: #개요
# Skipped: #역사
# Skipped: #파이썬_2
# Skipped: #파이썬_3
# Skipped: #기능과_철학
# Skipped: #라이브러리
# Skipped: #문법
# Skipped: #자료형
# Skipped: #동작하는_플랫폼
# Skipped: #한글_다루기
# Skipped: #사용_현황
# Skipped: #파이썬으로_작성된_자유-오픈_소스_소프트웨어
# Skipped: #파이썬을_내부적으로_사용하는_소프트웨어
# Skipped: #파이썬을_이용하고_있는_기업·정부_기관
# Skipped: #실행_속도_향상_관련
# Skipped: #비평
# Skipped: #같이_보기
# Skipped: #각주
# Skipped: #외부_링크
# Skipped: #cite_note-4
# Skipped: #cite_note-5
# Skipped: #cite_note-6
# Skipped: #cite_note-7
# Skipped: #cite_note-8
# Skipped: #cite_note-9
# Skipped: #cite_ref-1
# Skipped: #cite_ref-파이썬_역사_2-0
# Skipped: #cite_ref-3
# Skipped: #cite_ref-4
# Skipped: #cite_ref-5
# Skipped: #cite_ref-6
# Skipped: #cite_ref-7
# Skipped: #cite_ref-8
# Skipped: #cite_ref-9
#  https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC / 508
# Skipped: #curriculum
# Skipped: #review
# Skipped: #qna
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
#  https://programmers.co.kr/learn/courses/2 / 161
# Skipped: #_1
# Skipped: #_2
# Skipped: #_3
# Skipped: #_4
# Skipped: #_5
# Skipped: #if
# Skipped: #for
# Skipped: #while
# Skipped: #_6
# Skipped: #myModal
# Skipped: #myModal
# Skipped: #top
#  https://wikidocs.net/9 / 4
# Skipped: #myModal
# Skipped: #myModal
# Skipped: #top
#  https://wikidocs.net/43 / 3
# Skipped: #_1
# Skipped: #_2
# Skipped: #_3
# Skipped: #_4
# Skipped: #_5
# Skipped: #_6
# Skipped: #fn:opensource
# Skipped: #fn:library
# Skipped: #fn:indentation
# Skipped: #fnref:opensource
# Skipped: #fnref:library
# Skipped: #fnref:indentation
# Skipped: #myModal
# Skipped: #myModal
# Skipped: #top
#  https://wikidocs.net/6 / 5
# Skipped: #_1
# Skipped: #_2
# Skipped: #_3
# Skipped: #_4
# Skipped: #_5
# Skipped: #concatenation
# Skipped: #_6
# Skipped: #_7
# Skipped: #_8
# Skipped: #_9
# Skipped: #_10
# Skipped: #_11
# Skipped: #_12
# Skipped: #_13
# Skipped: #_14
# Skipped: #_15
# Skipped: #_16
# Skipped: #_17
# Skipped: #_18
# Skipped: #format
# Skipped: #f
# Skipped: #_19
# Skipped: #count
# Skipped: #1find
# Skipped: #2index
# Skipped: #join
# Skipped: #upper
# Skipped: #lower
# Skipped: #lstrip
# Skipped: #rstrip
# Skipped: #strip
# Skipped: #replace
# Skipped: #split
# Skipped: #_20
# Skipped: #fn:slicing
# Skipped: #fnref:slicing
# Skipped: #myModal
# Skipped: #myModal
# Skipped: #top
#  https://wikidocs.net/13 / 7
# Skipped: #
# Skipped: #everystudy
# Skipped: #
# Skipped: #comment97298
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment97101
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment97097
# Skipped: #
# Skipped: #comment96898
# Skipped: #
# Skipped: #comment96612
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment96564
# Skipped: #
# Skipped: #comment96503
# Skipped: #
# Skipped: #comment96413
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment95223
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment95051
# Skipped: #
# Skipped: #comment95024
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment94999
# Skipped: #
# Skipped: #comment94719
# Skipped: #
# Skipped: #comment94645
# Skipped: #
# Skipped: #comment93763
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment91809
# Skipped: #
# Skipped: #comment91378
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment91311
# Skipped: #
# Skipped: #comment91292
# Skipped: #
# Skipped: #comment90776
# Skipped: #
# Skipped: #comment89556
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment89270
# Skipped: #
# Skipped: #comment89109
# Skipped: #
# Skipped: #comment89043
# Skipped: #
# Skipped: #
# Skipped: #comment88099
# Skipped: #
# Skipped: #
# Skipped: #comment88074
# Skipped: #
# Skipped: #
# Skipped: #comment88073
# Skipped: #
# Skipped: #
# Skipped: #comment88071
# Skipped: #
# Skipped: #comment87923
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment87618
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment87457
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment87369
# Skipped: #
# Skipped: #comment87285
# Skipped: #
# Skipped: #comment87226
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment87198
# Skipped: #
# Skipped: #comment87067
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment86796
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment86434
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment85783
# Skipped: #
# Skipped: #comment85665
# Skipped: #
# Skipped: #comment85179
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment85135
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment85111
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment84968
# Skipped: #
# Skipped: #comment84758
# Skipped: #
# Skipped: #comment84693
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment84524
# Skipped: #
# Skipped: #comment84278
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #comment84182
# Skipped: #
# Skipped: #comment84067
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #close
#  https://opentutorials.org/course/1750 / 144
# Skipped: #content
# Skipped: #python-network
# Skipped: #top
# Skipped: #site-map
# Skipped: #
# Skipped: #
# Skipped: #python-network
# Skipped: #python-network
# > https://www.python.org/psf-landing/ / 128
# Skipped: #
# Skipped: #
# > https://docs.python.org / 14
# Skipped: #content
# > https://pypi.python.org/ / 45
# Skipped: #content
# Skipped: #python-network
# Skipped: #top
# Skipped: #site-map
# Skipped: #
# Skipped: #
# Skipped: #python-network
# Skipped: #python-network
# > https://www.python.org/jobs/ / 381
# Skipped: #content
# Skipped: #python-network
# Skipped: #top
# Skipped: #site-map
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #python-network
# Skipped: #python-network
# > https://www.python.org/community/ / 144
# Skipped: #content
# Skipped: #python-network
# Skipped: #top
# Skipped: #site-map
# Skipped: #
# Skipped: #
# Skipped: #python-network
# Skipped: #python-network
# > https://www.python.org/psf/donations/ / 121
# > https://plus.google.com/+Python / 51
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# Skipped: #
# > https://www.facebook.com/pythonlang?fref=ts / 86
# > https://twitter.com/ThePSF / 0
# Skipped: #content
# Skipped: #python-network
# Skipped: #top
# Skipped: #site-map
# Skipped: #
# Skipped: #
# Skipped: #python-network
# Skipped: #python-network
# > https://www.python.org/community/irc/ / 140
# Skipped: #content
# Skipped: #python-network
# Skipped: #top
# Skipped: #site-map
# Skipped: #
# Skipped: #
# Skipped: #python-network
# Skipped: #python-network
# > https://www.python.org/about/ / 171
# Skipped: #content
# Skipped: #python-network
# Skipped: #top
# Skipped: #site-map
# Skipped: #
# Skipped: #
# Skipped: #python-network
# Skipped: #python-network
# > https://www.python.org/about/apps/ / 179
# Skipped: #content
# Skipped: #python-network
# Skipped: #top
# Skipped: #site-map
# Skipped: #
# Skipped: #
# Skipped: #python-network
# Skipped: #python-network
# > https://www.python.org/about/quotes/ / 151
# Skipped: #content
# Skipped: #python-network
# Skipped: #top
# Skipped: #site-map
# Skipped: #
# Skipped: #
# Skipped: #python-network
# Skipped: #python-network
# > https://www.python.org/about/gettingstarted/ / 155
# Skipped: #content
# Skipped: #python-network
# Skipped: #top
# Skipped: #site-map
# Skipped: #
# Skipped: #
# Skipped: #python-network
# Skipped: #python-network
# > https://www.python.org/about/help/ / 158
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-fff46c9363e9> in <module>
#       6     seed = queue.pop(0)
#       7
# ----> 8     links = getUrls(seed["url"], seed["depth"])
#       9
#      10     if links != None:
#
# <ipython-input-74-366232ccb1ca> in getUrls(url, depth)
#       4         return None
#       5
# ----> 6     html = getDownload(url)
#       7
#       8     if html.status_code != 200:
#
# <ipython-input-2-e84ed32bc778> in getDownload(url, param, retries)
#       3
#       4     try:
# ----> 5         resp = requests.get(url, params = param, headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36'})
#       6         resp.raise_for_status()
#       7     except requests.exceptions.HTTPError as e:
#
# C:\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# C:\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     245                     proxies=proxies,
#     246                     allow_redirects=False,
# --> 247                     **adapter_kwargs
#     248                 )
#     249
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# C:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# C:\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# C:\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     342             or IS_SECURETRANSPORT):
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#     346         warnings.warn(
#
# C:\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     451         while True:
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#     455                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# C:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1904         :return: None.
#    1905         """
# -> 1906         result = _lib.SSL_do_handshake(self._ssl)
#    1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# KeyboardInterrupt:
