# %% [markdown]
# ## 1. What is Jupyter Notebook?

# %% [markdown]
# The Jupyter Notebook is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and explanatory text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, machine learning and much more.

# %% [markdown]
# ## 2. Live Code example

# %%
def add(a,b):
    return a+b

# %%
add(1,3)
# Out:
# 4

# %% [markdown]
# ## 3. Equations

# %%
#sqrt{x^2+y^2+z^2}

# %% [markdown]
#  $\sqrt{x^2+y^2+z^2}$

# %% [markdown]
# This expression $\sqrt{3x-1}+(1+x)^2$ is an example of a TeX inline equation in a [Markdown-formatted](http://daringfireball.net/projects/markdown/) sentence.

# %% [markdown]
# [More Example Click here](http://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html)

# %% [markdown]
# ## 4. Visualization

# %% [markdown]
# ### 4.1 image

# %%
from IPython.display import Image
Image(url="https://guides.github.com/images/logo@2x.png", width=200, height=500)
# Out:
# <img src="https://guides.github.com/images/logo@2x.png" width="200" height="500"/>

# %% [markdown]
# ### 4.2 Video

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('bRHG7YObDuU')

# %% [markdown]
# ### 4.3 Table

# %%
import pandas as pd
url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
pd.read_csv(url, nrows=10)
# Out:
#                     Country  Region
# 0                   Algeria  AFRICA
# 1                    Angola  AFRICA
# 2                     Benin  AFRICA
# 3                  Botswana  AFRICA
# 4                   Burkina  AFRICA
# 5                   Burundi  AFRICA
# 6                  Cameroon  AFRICA
# 7                Cape Verde  AFRICA
# 8  Central African Republic  AFRICA
# 9                      Chad  AFRICA

# %% [markdown]
# ### 4.4 Chart

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# [More Example Click here](https://matplotlib.org/examples/index.html)

# %% [markdown]
# ## 5. Performace check

# %%
# %time 3+4
# Out:
# Wall time: 0 ns
# 7

# %%
# %time add(3,4)
# Out:
# Wall time: 0 ns
# 7

# %%
# %timeit 3+4
# Out:
# 42 ns ± 4.6 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit add(3,4)
# Out:
# 312 ns ± 94.8 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
a = [1,2,3]
a = [x+1 for x in a]
print (a)
# Out:
# [2, 3, 4]

# %%
# %%timeit
a = [1,2,3]
a = [x+1 for x in a]
# Out:
# 1.97 µs ± 562 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
b = [1,2,3]
for i in range(len(b)):
    b[i] = b[i] +1
    
print(b)
# Out:
# [2, 3, 4]

# %%
# %%timeit
b = [1,2,3]
for i in range(len(b)):
    b[i] = b[i] +1
# Out:
# 3.11 µs ± 815 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
