# %% [markdown]
# ## **[MPG]** ggplot2 패키지에서 제공되는 연비관련 데이터

# %%
install.packages("ggplot2")
# Out:
# also installing the dependencies 'colorspace', 'RColorBrewer', 'dichromat', 'munsell', 'labeling', 'viridisLite', 'gtable', 'MASS', 'plyr', 'reshape2', 'scales', 'lazyeval'
# package 'colorspace' successfully unpacked and MD5 sums checked
# package 'RColorBrewer' successfully unpacked and MD5 sums checked
# package 'dichromat' successfully unpacked and MD5 sums checked
# package 'munsell' successfully unpacked and MD5 sums checked
# package 'labeling' successfully unpacked and MD5 sums checked
# package 'viridisLite' successfully unpacked and MD5 sums checked
# package 'gtable' successfully unpacked and MD5 sums checked
# package 'MASS' successfully unpacked and MD5 sums checked
# package 'plyr' successfully unpacked and MD5 sums checked
# package 'reshape2' successfully unpacked and MD5 sums checked
# package 'scales' successfully unpacked and MD5 sums checked
# package 'lazyeval' successfully unpacked and MD5 sums checked
# package 'ggplot2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\shpim\AppData\Local\Temp\Rtmp4KSl1E\downloaded_packages

# %%
library(ggplot2)

# %%
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
mpg1 <- mpg
avg_mileage <- (mpg1$cty+ mpg1$hwy) /2 
avg_mileage
# Out:
#   [1] 23.5 25.0 25.5 25.5 21.0 22.0 22.5 22.0 20.5 24.0 23.0 20.0 21.0 21.0 20.0
#  [16] 19.5 21.0 19.5 17.0 13.0 17.0 15.0 14.5 21.0 19.0 21.0 20.0 19.5 16.5 12.5
#  [31] 13.0 15.5 23.0 26.0 22.0 23.5 21.5 21.0 20.5 19.0 19.0 20.5 20.5 14.0 18.5
#  [46] 18.0 19.5 19.5 17.0 16.0 15.0 15.5 16.5 16.5 10.5 14.0 13.0 15.0 15.0 10.5
#  [61] 15.0 13.5 15.5 13.0 14.0 10.5 15.0 15.0 14.0 10.5 13.0 13.5 15.0 13.0 14.0
#  [76] 14.0 15.0 15.5 17.0 15.5 16.0 16.0 15.0 15.5 15.5 14.5 14.5 15.0 13.0 15.0
#  [91] 22.0 21.5 21.5 20.0 18.0 18.5 19.0 18.5 17.0 30.5 28.0 28.5 26.0 28.0 30.0
# [106] 30.5 30.0 25.0 22.0 22.5 25.5 26.0 22.0 22.0 23.5 22.5 24.0 24.0 23.5 20.5
# [121] 20.0 20.5 19.5 17.0 17.5 15.5 10.5 16.5 15.5 12.5 13.0 15.0 15.0 13.0 14.0
# [136] 13.5 15.0 15.5 16.0 16.0 15.0 25.0 23.0 27.0 27.5 23.0 22.5 22.0 22.0 22.0
# [151] 15.5 16.0 17.0 15.0 22.0 21.0 22.0 23.0 20.5 21.5 21.0 23.5 22.0 23.0 20.5
# [166] 23.5 22.5 22.5 22.5 22.5 23.5 22.0 23.5 17.5 18.0 17.0 16.0 18.0 15.5 25.0
# [181] 24.0 26.0 26.0 22.0 22.0 23.5 24.0 25.0 26.0 26.5 22.0 22.0 22.5 27.0 28.5
# [196] 30.5 32.5 30.5 13.0 15.5 17.5 18.0 19.5 16.0 17.0 16.5 18.0 25.0 22.5 25.0
# [211] 25.5 20.5 38.5 25.0 22.5 25.5 25.0 25.0 25.0 19.5 20.5 39.5 35.0 25.0 22.5
# [226] 24.0 24.5 25.0 23.5 23.5 25.0 21.0 22.0 21.5

# %%
length(avg_mileage)
# Out:
# [1] 234

# %%
mpg1$avg_mileage <- avg_mileage 
names(mpg1)
# Out:
#  [1] "manufacturer" "model"        "displ"        "year"         "cyl"
#  [6] "trans"        "drv"          "cty"          "hwy"          "fl"
# [11] "class"        "avg_mileage"

# %%
summary(mpg1$avg_mileage)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   10.50   15.50   20.50   20.15   23.50   39.50

# %%
round(mean(mpg1$avg_mileage),3)
# Out:
# [1] 20.15

# %%
table(mpg1$avg_mileage)
# Out:
# 10.5 12.5   13 13.5   14 14.5   15 15.5   16 16.5   17 17.5   18 18.5   19 19.5
#    5    2   10    3    7    3   17   13    8    5    9    3    6    3    4    8
#   20 20.5   21 21.5   22 22.5   23 23.5   24 24.5   25 25.5   26 26.5   27 27.5
#    5   10   10    5   19   12    6   11    6    1   14    5    6    1    2    1
#   28 28.5   30 30.5 32.5   35 38.5 39.5
#    2    2    2    4    1    1    1    1

# %%
hist(mpg1$avg_mileage)
# Out:
# Plot with title "Histogram of mpg1$avg_mileage"

# %%
qplot(mpg1$avg_mileage)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
hist(mpg1$avg_mileage,xlim=c(0,50), ylim=c(0,100),main="테스트", border=2)
# Out:
# Plot with title "테스트"

# %%
mpg1$test_result <- ifelse(mpg1$avg_mileage >= 20, "pass", "fail")

# %%
head(mpg1,10)
# Out:
#    manufacturer model      displ year cyl trans      drv cty hwy fl class
# 1  audi         a4         1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2  audi         a4         1.8   1999 4   manual(m5) f   21  29  p  compact
# 3  audi         a4         2.0   2008 4   manual(m6) f   20  31  p  compact
# 4  audi         a4         2.0   2008 4   auto(av)   f   21  30  p  compact
# 5  audi         a4         2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6  audi         a4         2.8   1999 6   manual(m5) f   18  26  p  compact
# 7  audi         a4         3.1   2008 6   auto(av)   f   18  27  p  compact
# 8  audi         a4 quattro 1.8   1999 4   manual(m5) 4   18  26  p  compact
# 9  audi         a4 quattro 1.8   1999 4   auto(l5)   4   16  25  p  compact
# 10 audi         a4 quattro 2.0   2008 4   manual(m6) 4   20  28  p  compact
#    avg_mileage test_result
# 1  23.5        pass
# 2  25.0        pass
# 3  25.5        pass
# 4  25.5        pass
# 5  21.0        pass
# 6  22.0        pass
# 7  22.5        pass
# 8  22.0        pass
# 9  20.5        pass
# 10 24.0        pass

# %%
mpg1$grade <- ifelse(mpg1$avg_mileage >= 30, "A", ifelse(mpg1$avg_mileage >=20,  "B","C"))

# %%
table(mpg1$grade)
# Out:
#   A   B   C
#  10 118 106
